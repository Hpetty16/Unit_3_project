# %% [markdown]
# # Unit 3 Project - Exploratory Data Analysis

# %% [markdown]
# ## Part 1 - Univariate Analysis - Visualization

# %% [markdown]
# ### Step 1 - Open Jupyter Notebook in New Virtual Environment

# %% [markdown]
# ###### This step should have been completed prior to opening the Jupyter Notebook. If it was not, create and activate your virtual environment, then restart your notebook within the venv.

# %% [markdown]
# ### Step 2 - Load DataFrame and Explore Dataset

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %%
# import pandas and numpy
import pandas as pd
import numpy as np

# %%
# load salary.csv into dataframe
df = pd.read_csv('salary.csv')

# %%
# look at first few values of dataframe
df.head()
# Out:
#    age gender    education  industry  industry_experience       salary
# 0   19   Male  high school  business                    0  33640.60752
# 1   21   Male  high school  business                    2  43554.24216
# 2   19   Male  high school  business                    0  39795.29424
# 3   22   Male  high school  business                    1  51102.98856
# 4   21   Male  high school  business                    1  32809.57056

# %%
# look at basic dataframe info
df.head()
# Out:
#    age gender    education  industry  industry_experience       salary
# 0   19   Male  high school  business                    0  33640.60752
# 1   21   Male  high school  business                    2  43554.24216
# 2   19   Male  high school  business                    0  39795.29424
# 3   22   Male  high school  business                    1  51102.98856
# 4   21   Male  high school  business                    1  32809.57056

# %% [markdown]
# ### Step 3 - Review Types of Basic Univariate Plots

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# #### Fill in blanks with a brief description of each plot type:
#
#
# - Histogram
# > It is used to summarize discrete or continuous data that are measured on an interval scale. It is often used to illustrate the major features of the distribution of the data in a convenient form. Less about individual data points and more broad.
# > Histograms are used to show the distribution of numerical data by presenting the frequency of data values. Values are organized into bins (Ranges) to show the spread of the data. This type of visualization would be useful to check for skewness.
# > Histograms are similar to bar charts which display the counts or relative frequencies of values falling in different class intervals or ranges. A histogram displays the shape and spread of continuous sample data. It also helps us understand the skewness and kurtosis of the distribution of the data.
# - Density Plot / KDE
# > A density chart displays the relationship between 2 numeric variables, where one variable is represented on the X-axis, the other on the Y axis, like for a scatterplot. You should use a density distribution when there are a large number of data points and risk overplotting in a scatterplot. A density plot can represent an otherwise hidden pattern of the density distribution indicating density differences using color.
# > A density plot is like a smoother version of a histogram. Generally, the kernel density estimate is used in density plots to show the probability density function of the variable. A continuous curve, which is the kernel is drawn to generate a smooth density estimation for the whole data.
# - Bar Chart
# > Used to compare and contrast numbers, frequencies or other measures of distinct categories of data. Bar graphs are used to compare things between different groups or to track changes over time. However, when trying to measure change over time, bar graphs are best when the changes are larger.
# > Bar charts are useful for visualizing the count of nominal/categorical data. Bar charts are a great alternative to the issues that arise with pie charts.
# - Line Plot
# > A line plot visualizes data by connecting the data points via line segments. It is similar to a scatter plot except that the measurement points are ordered (typically by their x-axis value) and joined with straight line segments.The matplotlib plt.plot() function by default plots the data using a line plot.
# - Univariate scatter plot
# > This plots different observations/values of the same variable corresponding to the index/observation number.The scatter() function requires two parameters to plot. Then visualize the same plot by considering its variety using the sns.scatterplot() function of the seaborn library.
# - Violin Plot
# > A hybrid of a box plot and a kernel density plot, which shows peaks in the data. It is used to visualize the distribution of numerical data. Unlike a box plot that can only show summary statistics, violin plots depict summary statistics and the density of each variable.
# - Box Plot
# > Box plots are also used to look at the spread of your data. These visualizations also give you descriptive statistics that are not featured in histograms. You can change the orientation of your box plot by changing the data variable (from y to x).  As with the histogram, you can add and modify visualization elements by using the update_traces() method (as well as update_layout and other plotly methods).
# - Pie Chart
# > Though pie charts are highly contested in the realm of data analytics and visualization, they may offer insight for further analysis. Pie charts allow you to visualize value distribution for nominal or ordinal data.Use pie chart arguments to change the appearance of your visualization. Since we are assigning colors to parental education category, you will need to use Plotly's sequential colors to ensure that each category is assigned a unique color.
# - Rug Plot
# > A rug plot is a very simple, but also an ideal legitimate, way of representing a distribution. It consists of vertical lines at each data point. Here, the height is arbitrary. The density of the distribution can be known by how dense the tick-marks are.

# %% [markdown]
# ### Step 4 - Choose Which Plot(s) You Will Use for Each Variable

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# #### Take a moment to plan what types of plots you will make for each variable
# - age
# > Histogram
# - gender
# > Pie Chart
# - education
# > Pie Chart
# - industry
# > Count Plot
# - industry experience
# > Histogram
# - salary
# > Violin Plot

# %% [markdown]
# ### Step 5 - Create Plots for Each Variable in Dataset

# %%
import matplotlib.pyplot as plt #imports matplotlib

import seaborn as sns #imports seaborn

# %matplotlib inline #make plots appear automatically in notebook

sns.set() #sets default styling to seaborn

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# ### Plot for 'age' column

# %%
# sets figure size
plt.figure(figsize=(12,6))

# establishes figure with data and plot type
ax = sns.histplot(data=df, x='age', palette="viridis", bins=8)

# sets x and y labels
plt.xlabel("Age", fontsize=14)
plt.ylabel("Number of Managers", fontsize=14)

# sets title
plt.title("Distribution of Manager Ages in Survey", fontsize=15);

# %% [markdown]
# ##### Insights:
#
# Managers are typically older in age; The older a person is the more likely they are to become a manager.

# %% [markdown]
# ### Plot for 'industry' column

# %%
plt.figure(figsize=(10,10))

data = df['industry'].value_counts()

labels = ["Healthcare", "Technology", "Finance", "Business"]

colors = sns.color_palette('Set2')

plt.title("% Of Managers In Each Industry", fontsize=16)

ax = plt.pie(data, colors = colors, labels = labels, autopct = '%.0f%%');

# %% [markdown]
# ##### Insights:
#
# The four industries included are approximately equal in representation, around twenty-five percent of the data per industry.

# %% [markdown]
# ### Plot for 'salary' column

# %%
plt.figure(figsize=(12,6))

sns.violinplot(x=df['salary'], color = "Green")

plt.xlabel("Salary", fontsize=14)
plt.title("Density of Manager Salaries");

# %% [markdown]
# ##### Insights:
#
# The mean appears to be around the 100K point with salaries ascending and decending under and over 100K.

# %% [markdown]
# ### Plot for 'industry_experience' column

# %%
plt.figure(figsize=(12,6))

ax = sns.histplot(data=df, x='industry_experience', bins=20)

plt.xlabel("Industry Experience ", fontsize=13)
plt.ylabel("Number of Managers", fontsize=13)
plt.title("Industry Experience Among Managers", fontsize=16);

# %% [markdown]
# ##### Insights:
#
# The average industry experience is around 20 years

# %% [markdown]
# ### Plot for 'education' column

# %%
df['education'].value_counts()
# Out:
# bachelors degree    10972
# masters degree       8979
# some college         4707
# high school           781
# Name: education, dtype: int64

# %%
plt.figure(figsize=(10,10))

data = df['education'].value_counts()

labels = ["Bachelor's Degree", "Master's Degree", "Some College", "High School"]

colors = sns.color_palette('flare')

plt.title("Manager's Education Levels", fontsize=16)

ax = plt.pie(data, colors = colors, labels = labels, autopct = '%.0f%%');

# %% [markdown]
# ##### Insights:
#
# Majority of managers hold a bachelor's degree, The next hightest representation being a Master's degree. With very few managers have only a high school diploma.

# %% [markdown]
# ### Plot for 'gender' column

# %%
plt.figure(figsize=(10,10))

data = df['gender'].value_counts()

labels = ['Male', 'Female']

colors = sns.color_palette('rainbow')

ax = plt.pie(data, colors=colors, labels=labels, autopct='%.0f%%');

# %% [markdown]
# ##### Insights:
#
# Gender is equal

# %% [markdown]
# ## Part 2 - Summary Statistics

# %% [markdown]
# ### Step 1 - Review Summary Statistics

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# - mean
# > Mean is the average of the given numbers and is calculated by dividing the sum of given numbers by the total number of numbers. In addition, the mean is the only measure of central tendency where the sum of the deviations of each value from the mean is always zero.
# - median
# >  The median is the middle number in a sorted, ascending or descending list of numbers and can be more descriptive of that data set than the average. It is the point above and below which half (50%) the observed data falls, and so represents the midpoint of the data.
# - mode
# > The mode in statistics refers to a number in a set of numbers that appears the most often. For example, if a set of numbers contained the following digits, 1, 1, 3, 5, 6, 6, 7, 7, 7, 8, the mode would be 7, as it appears the most out of all the numbers in the set.
# - central tendency
# > Central tendency is defined as “the statistical measure that identifies a single value as representative of an entire distribution.” It aims to provide an accurate description of the entire data. It is the single value that is most typical/representative of the collected data.
# - distribution
# > A statistical distribution, or probability distribution, describes how values are distributed for a field. In other words, the statistical distribution shows which values are common and uncommon. There are many kinds of statistical distributions, including the bell-shaped normal distribution.
# - variance
# > The variance is a measure of variability. It is calculated by taking the average of squared deviations from the mean. Variance tells you the degree of spread in your data set. The more spread the data, the larger the variance is in relation to the mean.
# - standard deviation
# > Standard deviation is a statistic that measures the dispersion of a dataset relative to its mean and is calculated as the square root of the variance. The standard deviation is calculated as the square root of variance by determining each data point's deviation relative to the mean.

# %% [markdown]
# ### Step 2 - Find  & Report Summary Statistics For Numeric Variables

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# #### Age Summary Statistics

# %%
df['age'].describe()
# Out:
# count    25439.000000
# mean        46.219466
# std         12.758662
# min         18.000000
# 25%         36.000000
# 50%         47.000000
# 75%         57.000000
# max         67.000000
# Name: age, dtype: float64

# %%
plt.figure(figsize=(12,4))

plt.title("Age Distribution Among Managers", fontsize=16)

sns.boxplot(x=df['age'])

plt.xlabel("Manager Age", fontsize=14);

# %% [markdown]
# - age **mean**
# > The mean age is 46.219466
# - age **median**
# > The median age is 47.000000
# - age **minimum**
# > The minimum age is 18.000000
# - age **maximum**
# > The maximum age is 67.000000
# - age **standard deviation**
# > The standard deviation is 12.758662

# %% [markdown]
# ###### Reflection: How did mean and median differ above? Why do you think that is?
#
# Their is a year difference beween the mean and median.

# %% [markdown]
# #### Salary Summary Statistics

# %%
df['salary'].describe()
# Out:
# count     25439.000000
# mean     101416.000070
# std       26136.687123
# min       28054.080000
# 25%       84621.294048
# 50%      101148.480000
# 75%      119828.075728
# max      175223.321900
# Name: salary, dtype: float64

# %%
plt.figure(figsize=(12,4))

plt.title("Distribution of Salary Among Managers", fontsize=16)

sns.boxplot(x=df['salary'])

plt.xlabel("Annual Salary (USD)", fontsize=14);

# %% [markdown]
# - Salary **mean**
# > The mean salary is 101416.000070
# - Salary **median**
# > The median salary is 101148.480000
# - Salary **minimum**
# > The minimum salary is 28054.080000
# - Salary **maximum**
# > The maximum salary is 175223.321900
# - Salary **standard deviation**
# > The standard deviation is 26136.687123

# %% [markdown]
# ###### Reflection: How did mean and median differ above? Why do you think that is?
#
# The mean and median differed by $268. I believe this to be true because the median collects the middle portion of data, while mean collects the avaerage.

# %% [markdown]
# ### Step 3 - Find Salary Summary Statistics By Industry

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %%
df['salary'].groupby(df['industry']).describe()
# Out:
#              count           mean           std          min           25%  \
# industry
# business    6367.0   98296.471387  24822.138864  29340.67968  82482.816000
# finance     6383.0  102838.541755  26344.729075  30747.52224  86224.406400
# healthcare  6307.0   94767.547447  23696.008298  28054.08000  79538.185000
# technology  6382.0  109675.753478  27127.404233  32704.34400  92223.969112
#
#                      50%            75%           max
# industry
# business     98200.01048  116110.250464  159030.78048
# finance     102692.33568  122237.832000  166370.21852
# healthcare   94728.96000  112058.784000  152775.98600
# technology  109130.17575  129758.177182  175223.32190

# %%
df['salary'].groupby(df['industry']).median()
# Out:
# industry
# business       98200.01048
# finance       102692.33568
# healthcare     94728.96000
# technology    109130.17575
# Name: salary, dtype: float64

# %%
plt.figure(figsize=(12,8))

ax = sns.boxplot(data=df, x='industry', y='salary')

plt.xlabel("Industry", fontsize=14)
plt.ylabel("Salary", fontsize=14)
plt.title("Distribution of Salaries Across Industries", fontsize=16);

# %% [markdown]
# ##### Insights:
#
# Salaries in the different fields are all similar, with technology averging the highest.

# %% [markdown]
# ### Step 4 - Find Salary Summary Statistics By Education

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %%
df['salary'].groupby(df['education']).describe()
# Out:
#                     count           mean           std        min  \
# education
# bachelors degree  10972.0  100710.905311  20960.707146  40962.240
# high school         781.0   47602.924607  10556.975508  28054.080
# masters degree     8979.0  115583.500303  21594.533546  68037.024
# some college       4707.0   84962.702227  24994.963474  29030.208
#
#                            25%            50%           75%           max
# education
# bachelors degree  85154.097000   98829.004800  115799.14680  159790.23450
# high school       39832.128000   46255.446000   53930.62080   78486.86520
# masters degree    98782.553760  113936.908800  131988.10416  175223.32190
# some college      68385.261696   84824.902426  103041.44640  149241.93034

# %%
df['salary'].groupby(df['education']).median()
# Out:
# education
# bachelors degree     98829.004800
# high school          46255.446000
# masters degree      113936.908800
# some college         84824.902426
# Name: salary, dtype: float64

# %%
plt.figure(figsize=(12,8))

ax = sns.boxplot(data=df, x='education', y='salary')

plt.xlabel("Education", fontsize=14)
plt.ylabel("Salary", fontsize=14)
plt.title("Salary Distribution By Education Level", fontsize=16);

# %% [markdown]
# ##### Insights:
#
# The more schooling you have the more you can expect to earn

# %% [markdown]
# ### Step 5 - Find Salary Summary Statistics by Gender

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %%
df['salary'].groupby(df['gender']).describe()
# Out:
#           count           mean           std        min         25%  \
# gender
# Female  12730.0   98209.928810  24978.233860  28054.080  81938.1888
# Male    12709.0  104627.368954  26867.859585  29725.182  87625.1900
#
#                 50%          75%          max
# gender
# Female   98057.3880  115867.1844  163708.4064
# Male    104240.0788  123838.3008  175223.3219

# %%
df['salary'].groupby(df['gender']).median()
# Out:
# gender
# Female     98057.3880
# Male      104240.0788
# Name: salary, dtype: float64

# %%
plt.figure(figsize=(12,8))

ax = sns.boxplot(data=df, x='gender', y='salary')

plt.xlabel("Gender", fontsize=14)
plt.ylabel("Salary", fontsize=14)
plt.title("Distribution of Salary By Gender", fontsize=16);

# %% [markdown]
# ##### Insights:
#
# Men on average have a higer salary than women.

# %% [markdown]
# ## Part 3 - Looking for Relationships in Data

# %% [markdown]
# ### Step 1 - Review Useful Tools for Bivariate Relationships

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# #### Fill in the blanks below with brief explanations of each type of plot listed
#
# - **Categorical Data**
# > ***Contingency Table***
# >
# >A contingency table is a special type of frequency distribution table, where two variables are shown simultaneously. For example, a researcher might be investigating the relationship between AIDS and sexual preference. The two variables would be AIDS and SEXUAL PREFERENCE.
# >
# > ***Clustered Bar Chart***
# >
# >A clustered bar chart is a chart where bars of different graphs are placed next to each other. It is a primary type of Excel chart. It compares values across categories by using vertical or horizontal bars. A clustered bar chart in Excel displays more than one data series in clustered horizontal or vertical columns.
#
# - **Mixed Data**
# > ***Individual Value Plot***
# >
# >An individual value plot shows a dot for the actual value of each observation in a group, making it easy to spot outliers and see distribution spread. An individual value plot works best when the sample size is less than approximately 50.
# >
# > ***Strip Plot***
# >
# >A strip plot is a single-axis scatter plot that is used to visualise the distribution of many individual one-dimensional values. The values are plotted as dots along one unique axis, and the dots with the same value can overlap. To show overlapping values, the opacity or colour of the dots can be changed, or a jitter plot or counts plot can be used instead. Typically, several strip plots are placed side by side to compare the distributions of data points among several values, categories or ranges.
#
# - **Quantitative Data**
# > ***Scatter plots***
# >
# > Scatter plots (also called scatter graphs) are similar to line graphs. A line graph uses a line on an X-Y axis to plot a continuous function, while a scatter plot uses dots to represent individual pieces of data. In statistics, these plots are useful to see if two variables are related to each other. For example, a scatter chart can suggest a linear relationship (i.e. a straight line).

# %% [markdown]
# ### Step 2 - Create Bivariate Plots & Tables

# %% [markdown]
# In the end of Part 2, you began looking at relationships between variables when you created boxplots which visualized the distribution of salary across different categories. In this step, you will make plots and visualizations to begin looking deeper for patterns and relationships between two variables.

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# ### Use the Pandas Crosstab() function to compare categorical variables

# %% [markdown]
# #### crosstab of gender and education

# %%
pd.crosstab(index=df['gender'], columns=df['education'])
# Out:
# education  bachelors degree  high school  masters degree  some college
# gender
# Female                 5468          387            4514          2361
# Male                   5504          394            4465          2346

# %% [markdown]
# ##### Insights:
#
# Bachelor's degree is the largest variable for both Female and Male. There are more Masters degrees associated with Female than Male.

# %% [markdown]
# ### Strip plot between age and education

# %%
plt.figure(figsize=(12,8))

ax = sns.stripplot(y=df['age'], x=df['education'])

# %% [markdown]
# ##### Insights:
#
# It shows that the younger a person is the less education they have

# %% [markdown]
# ### Scatterplot for age and salary

# %%
sns.scatterplot(x=df['age'], y=df['salary'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='salary'>

# %% [markdown]
# ##### Insights:
#
# People eho are older usually have a higher salary

# %% [markdown]
# ### Scatterplot for industry experience and salary

# %%
sns.scatterplot(x=df['industry_experience'], y=df['salary'])
# Out:
# <AxesSubplot:xlabel='industry_experience', ylabel='salary'>

# %% [markdown]
# ##### Insights:
#
# The more expericene a person has in there industry, the more they can expect to get paid.

# %% [markdown]
# ### Step 3 - Pick Two More Bivariate Relationships to Visualize

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %%
# create 1st visualization for bivariate relationship of your choice
plt.figure(figsize=(10,4))

ax = sns.stripplot(y=df['salary'], x=df['gender'])

# %%
# create 2nd visualization for bivariate relationship of your choice
plt.figure(figsize=(10,4))

ax = sns.stripplot(y=df['salary'], x=df['education'])

# %% [markdown]
# ## Part 4 - Correlation & Hypothesis Testing

# %% [markdown]
# ### Step 1 - Review Correlation

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# #### Fill in blanks with brief description of the following terms:
#
#
# - **Correlation**
# > A positive correlation is a relationship between two variables in which both variables move in the same direction. Therefore, when one variable increases as the other variable increases, or one variable decreases while the other decreases. An example of positive correlation would be height and weight.
#
# - **Correlation Coefficient**
# >A correlation coefficient is a number between -1 and 1 that tells you the strength and direction of a relationship between variables. In other words, it reflects how similar the measurements of two or more variables are across a dataset. Correlation coefficient value.

# %% [markdown]
# ### Step 2 - Review Hypothesis Testing & P-Value

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# #### Fill in blanks with brief description of the following terms:
#
# - **Hypothesis**
# > Hypotheses are usually written as if/then statements, such as if someone eats a lot of sugar, then they will develop cavities in their teeth. These statements identify specific variables (in this case, eating a large amount of sugar) and propose a result (in this case, teeth developing cavities).
#
# - **Null Hypothesis**
# > The null hypothesis is a typical statistical theory which suggests that no statistical relationship and significance exists in a set of given single observed variable, between two sets of observed data and measured phenomena.To write a null hypothesis, first start by asking a question. Rephrase that question in a form that assumes no relationship between the variables. In other words, assume a treatment has no effect.Examples of the Null Hypothesis.
# Question	                                 Null Hypothesis
# Do cats care about the color of their food?	Cats express no food preference based on color.
#
# - **P-Value**
# > The p-value is a number, calculated from a statistical test, that describes how likely you are to have found a particular set of observations if the null hypothesis were true. P-values are used in hypothesis testing to help decide whether to reject the null hypothesis.

# %% [markdown]
# ### Step 3 - Use Pearsonr & Spearmanr To Answer Questions About Correlation and P-Values

# %% [markdown]
# <h3 style='color:red;'> First, load 'salary_numeric.csv' - where education has been re-expressed as numeric variables.</h3>

# %%
df = pd.read_csv('salary_numeric.csv')

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %%
from scipy.stats import pearsonr, spearmanr

# %% [markdown]
# ### What is the correlation between salary and education?

# %% [markdown]
# #### Your Hypothesis = [...]

# %%
spearmanr(df['salary'], df['education'])
# Out:
# SpearmanrResult(correlation=0.47719759648149285, pvalue=0.0)

# %% [markdown]
# There is a small positive correlation between education level and salary

# %% [markdown]
# #### Are these results statistically significant? How do you know?

# %% [markdown]
# The correlation is statistically significant because the pvalue is 0. Anything lower than .05 is considered significant.

# %% [markdown]
# ### What is the correlation between salary and age?

# %% [markdown]
# #### Your Hypothesis [...]

# %%
pearsonr(df['salary'], df['age'])
# Out:
# (0.6631258539501858, 0.0)

# %% [markdown]
# There is a slight positive correlation between salary and age.

# %% [markdown]
# #### Are these results statistically significant? How do you know?

# %% [markdown]
# The pvalue is below .05 at 0, which is significant.

# %% [markdown]
# ### What is the correlation between salary and industry experience?

# %% [markdown]
# #### Your Hypothesis = [...]

# %%
spearmanr(df['salary'], df['industry_experience'])
# Out:
# SpearmanrResult(correlation=0.5910071254047617, pvalue=0.0)

# %% [markdown]
# There is a slight positive correlation between salary and industry_experience.

# %% [markdown]
# #### Are these results statistically significant? How do you know?

# %% [markdown]
# The pvalue is below .05 at 0, which is significant.

# %% [markdown]
# ### Step 4 - Report Findings

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# ### What was the null hypothesis for the relationships between education and salary, age and salary, and industry experience and salary?

# %% [markdown]
# There is no correlation between education, age, or industry experience and salary.

# %% [markdown]
# ### Can you reject the null hypothesis for any of the relationships you explored above?

# %% [markdown]
# Yes, the null hypotheses can be rejected because a relationship does exist between variables.

# %% [markdown]
# ## Part 5 - Multivariate Analysis

# %% [markdown]
# ### Step 1 - Review Types of Multivariate Analysis

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# #### Fill in the blanks with a brief description of each plot type
#
# - pairplots
# > Pair plot is used to understand the best set of features to explain a relationship between two variables or to form the most separated clusters. It also helps to form some simple classification models by drawing some simple lines or make linear separation in our data-set.
# - paired scatter plots
# > A pairs plot is a matrix of scatterplots that lets you understand the pairwise relationship between different variables in a dataset.
# - correlation matrix
# > A correlation matrix is a table showing correlation coefficients between variables. Each cell in the table shows the correlation between two variables. A correlation matrix is used to summarize data, as an input into a more advanced analysis, and as a diagnostic for advanced analyses.
# - heatmap
# > A heat map is a two-dimensional representation of data in which values are represented by colors. A simple heat map provides an immediate visual summary of information. More elaborate heat maps allow the viewer to understand complex data sets. A heat map (or heatmap) is a data visualization technique that shows magnitude of a phenomenon as color in two dimensions. The variation in color may be by hue or intensity, giving obvious visual cues to the reader about how the phenomenon is clustered or varies over space.

# %% [markdown]
# ### Step 2 - Create Pairplots for Dataset

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# #### pairplot of whole dataframe

# %%
sns.pairplot(df)

# %% [markdown]
# ##### Insights:
#
# The graps that were the most populated have the highest similarities to one another

# %% [markdown]
# ### Step 3 - Create Other Multivariate Plots

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# ### Correlation matrix

# %%
df.corr()
# Out:
#                           age  education  industry_experience    salary
# age                  1.000000   0.358189             0.842555  0.663126
# education            0.358189   1.000000             0.348966  0.538828
# industry_experience  0.842555   0.348966             1.000000  0.620691
# salary               0.663126   0.538828             0.620691  1.000000

# %% [markdown]
# ### Heatmap of correlation matrix

# %%
plt.figure(figsize=(12,8))

ax = sns.heatmap(df.corr(), annot=True, cmap='YlGnBu')

# %% [markdown]
# ##### Insights:
#
# The most similar to one another is industry experience and age, and age and salary

# %% [markdown]
# #### Crosstab of average salary grouped by education and industry

# %%
pd.crosstab(index=df['industry'], columns=df['education'], values=df['salary'], aggfunc=np.mean).round(0)
# Out:
# education        12       14        16        18
# industry
# business    46727.0  81647.0   97618.0  112037.0
# finance     48132.0  85814.0  102401.0  117568.0
# healthcare  44772.0  80221.0   94149.0  107954.0
# technology  51156.0  92362.0  108436.0  124632.0

# %% [markdown]
# #### Heatmap of crosstab of average salary grouped by education and industry

# %%
crosstab = pd.crosstab(index=df['industry'], columns=df['education'], values=df['salary'], aggfunc=np.mean).round(0)

# %%
plt.figure(figsize=(16,10))

ax = sns.heatmap(crosstab, annot=True, linewidths=.5, cmap='YlGnBu', fmt='g', xticklabels=['High School', 'Some College', "Bachelor's Degree", "Master's Degree"])

plt.xlabel("Education Level", fontsize=14)
plt.ylabel("Industry", fontsize=14)

plt.title("Manager Salaries Across Industries by Education Level", fontsize=18);

# %% [markdown]
# ##### Insights:
#
# Health care is the lowest paid indutry regardless of education, also the more education you have the more you get paid. The technology industry is the highest paid industry when it comes to any level of education.

# %% [markdown]
# ### Step 4 - Report Findings

# %%
################################### TO DO #########################################
  
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# ###### Along the way throughout this project, you should have been taking notes on insights from your exploratory data analysis. Take some time in a markdown cell below to write a couple paragraphs summarizing any observations, insights, conclusions, or further questions you have based on the exploratory analysis you conducted this week.

# %% [markdown]
# The way all of the data is shown on the plots lets you visualize the relationships between the data.The most evident correlation when looking at the variables were industry experience and age and the second most evident was age and salary, also the amount of education a person recieves strongly correlates how much they end up making as a salary. With all of this data we can see that professionals with higher education levels and more exprince in their industry can expect to earn the most in their respective fields.
#
# Heat maps are hard when comparing similar data to one another, also they are more difficult to read overall. My favorite part of the whole project was being able to make and currate the graphs to help better showcase the data. I think this project was very useful in helping better visualize the data that we have been going over the last couple of weeks.

# %% [markdown]
# ### Step 5 - Submit Project

# %% [markdown]
# ###### Push to GitHub, record brief code review video, and share links with Tech Lead and SME.
